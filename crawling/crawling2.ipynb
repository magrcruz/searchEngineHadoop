# %%
import requests
import re
from bs4 import BeautifulSoup

# URL de la página de Wikipedia a la que deseas hacer web scraping
url = "https://es.wikipedia.org/wiki/Algoritmo"

# Realizar una solicitud HTTP para obtener el contenido de la página
response = requests.get(url)

if response.status_code == 200:
    page_content = response.text
    soup = BeautifulSoup(page_content, "html.parser")

    # Extraer el título de la página
    title = soup.find("h1").text

    # Extraer el contenido del artículo (puede variar según la estructura de la página)
    content = ""

    # Definir una expresión regular para filtrar los enlaces no deseados
    pattern = re.compile(r"/wiki/.*:|/wiki/Wiki")

    # Extraer los enlaces salientes que cumplan con la expresión regular
    outgoing_links = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("/wiki/") and not pattern.match(a["href"])]

    # Imprimir o almacenar los datos
    print("Título:", title)
    print("Contenido:\n", content)
    for link in outgoing_links:
        print(link)

else:
    print("No se pudo obtener la página")
# Out:
# Título: Algoritmo
# Contenido:
#
# /wiki/Algoritmo
# /wiki/Algoritmo
# /wiki/Algoritmo
# /wiki/Logaritmo
# /wiki/Diagrama_de_flujo
# /wiki/Ada_Lovelace
# /wiki/Matem%C3%A1ticas
# /wiki/L%C3%B3gica
# /wiki/Ciencias_de_la_computaci%C3%B3n
# /wiki/Lat%C3%ADn_tard%C3%ADo
# /wiki/%C3%81rabe_cl%C3%A1sico
# /wiki/Empleador
# /wiki/Matem%C3%A1tica
# /wiki/Algoritmo_de_multiplicaci%C3%B3n
# /wiki/C%C3%A1lculo
# /wiki/Divisi%C3%B3n_(matem%C3%A1ticas)
# /wiki/Algoritmo_de_Euclides
# /wiki/M%C3%A1ximo_com%C3%BAn_divisor
# /wiki/N%C3%BAmeros_enteros
# /wiki/Eliminaci%C3%B3n_de_Gauss-Jordan
# /wiki/Sistema_de_ecuaciones_lineales
# /wiki/C%C3%A1lculo
# /wiki/Problema_abstracto
# /wiki/Criba_de_Erat%C3%B3stenes
# /wiki/Alonzo_Church
# /wiki/C%C3%A1lculo_lambda
# /wiki/Alan_Turing
# /wiki/M%C3%A1quina_de_Turing
# /wiki/Grafo
# /wiki/Estructura_de_datos
# /wiki/Algoritmo_paralelo
# /wiki/L%C3%B3gica_matem%C3%A1tica
# /wiki/M%C3%A9todo_de_Newton
# /wiki/Eliminaci%C3%B3n_de_Gauss-Jordan
# /wiki/Tesis_de_Church-Turing
# /wiki/Lenguaje_natural
# /wiki/Pseudoc%C3%B3digo
# /wiki/Diagramas_de_flujo
# /wiki/Lenguaje_de_programaci%C3%B3n
# /wiki/Teorema
# /wiki/Diagrama_de_flujo
# /wiki/Diagrama_de_flujo
# /wiki/Organizaci%C3%B3n_Internacional_para_la_Estandarizaci%C3%B3n
# /wiki/Pseudoc%C3%B3digo
# /wiki/Teor%C3%ADa_de_aut%C3%B3matas
# /wiki/Funci%C3%B3n_recursiva
# /wiki/M%C3%A1quina_de_Turing
# /wiki/M%C3%A1quina_de_registro
# /wiki/Funci%C3%B3n_recursiva
# /wiki/Lenguaje_m%C3%A1quina
# /wiki/Programa_(computaci%C3%B3n)
# /wiki/Red_neuronal_artificial
# /wiki/Algoritmo_de_multiplicaci%C3%B3n
# /wiki/Algoritmo_de_Euclides
# /wiki/Criba_de_Erat%C3%B3stenes
# /wiki/Formas_de_resolver_la_ra%C3%ADz_cuadrada
# /wiki/Teor%C3%ADa_de_la_computabilidad
# /wiki/Camino_hamiltoniano
# /wiki/Funci%C3%B3n_matem%C3%A1tica
# /wiki/Problema_abstracto
# /wiki/Bit
# /wiki/N%C3%BAmero_natural
# /wiki/Sistema_binario
# /wiki/Teor%C3%ADa_de_c%C3%B3digos
# /wiki/Bucle_infinito
# /wiki/Funci%C3%B3n_parcial
# /wiki/Dominio_de_definici%C3%B3n
# /wiki/Funci%C3%B3n_computable
# /wiki/Problema_de_la_parada
# /wiki/An%C3%A1lisis_de_algoritmos
# /wiki/Ciencias_de_la_computacion
# /wiki/Lenguaje_de_programaci%C3%B3n
# /wiki/Pseudoc%C3%B3digo
# /wiki/Lexico
# /wiki/C%C3%B3digo_binario
# /wiki/Algoritmo_de_Euclides
# /wiki/Conjunto
# /wiki/Pseudoc%C3%B3digo
# /wiki/C%2B%2B
# /wiki/Algoritmo_de_ordenamiento
# /wiki/Algoritmo_de_b%C3%BAsqueda
# /wiki/Algoritmo_voraz
# /wiki/Algoritmos_paralelos
# /wiki/Algoritmo_probabil%C3%ADstico
# /wiki/Algoritmo_determin%C3%ADstico
# /wiki/Algoritmo_no_determin%C3%ADstico
# /wiki/Divide_y_vencer%C3%A1s
# /wiki/Metaheur%C3%ADsticas
# /wiki/Programaci%C3%B3n_din%C3%A1mica_(computaci%C3%B3n)
# /wiki/Ramificaci%C3%B3n_y_acotaci%C3%B3n
# /wiki/Vuelta_atr%C3%A1s
# /wiki/Cota_inferior_asint%C3%B3tica
# /wiki/Cota_ajustada_asint%C3%B3tica
# /wiki/Complejidad_computacional
# /wiki/Diagrama_de_flujo
# /wiki/Diagrama_Nassi-Shneiderman
# /wiki/M%C3%A1quina_de_Turing
# /wiki/Ciencias_de_la_Computaci%C3%B3n
# /wiki/An%C3%A1lisis_de_algoritmos
# /wiki/Complejidad_computacional
# /wiki/Gobierno_por_algoritmos
# /wiki/Inform%C3%A1tica
# /wiki/Inteligencia_artificial
# /wiki/Investigaci%C3%B3n_operativa
# /wiki/Matem%C3%A1ticas
# /wiki/Programaci%C3%B3n
# /wiki/ISBN
# /wiki/Thomas_H._Cormen
# /wiki/MIT_Press
# /wiki/ISBN
# /wiki/ISBN
# /wiki/ISBN
# /wiki/ISBN
# /wiki/ISSN
# /wiki/ISBN
# /wiki/ISBN
# /wiki/ISSN
# /wiki/ISBN
# /wiki/Rivest,_R._L.
# /wiki/Gilles_Brassard
# /wiki/Knuth,_D._E
# /wiki/TeX
# /wiki/Lenguaje_de_programaci%C3%B3n_Java
# /wiki/JSTOR
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/ISBN
# /wiki/ISBN
# /wiki/George_Boolos
# /wiki/ISBN
# /wiki/ISBN
# /wiki/Alonzo_Church
# /wiki/JSTOR
# /wiki/Digital_object_identifier
# /wiki/Alonzo_Church
# /wiki/JSTOR
# /wiki/Digital_object_identifier
# /wiki/JSTOR
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/ISBN
# /wiki/G%C3%B6del
# /wiki/Alonzo_Church
# /wiki/Alan_Turing
# /wiki/Emil_Post
# /wiki/ISBN
# /wiki/Gottfried_Leibniz
# /wiki/George_Boole
# /wiki/Gottlob_Frege
# /wiki/Georg_Cantor
# /wiki/David_Hilbert
# /wiki/John_von_Neumann
# /wiki/Joseph-Marie_Jacquard
# /wiki/Babbage
# /wiki/Ada_Lovelace
# /wiki/Claude_Shannon
# /wiki/Howard_Aiken
# /wiki/Digital_object_identifier
# /wiki/Bibcode
# /wiki/ISBN
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/ISBN
# /wiki/Jean_van_Heijenoort
# /wiki/ISBN
# /wiki/ISBN
# /wiki/Andrew_Hodges
# /wiki/Simon_and_Schuster
# /wiki/Bibcode
# /wiki/ISBN
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/Stephen_Kleene
# /wiki/Semantic_Scholar
# /wiki/Digital_object_identifier
# /wiki/Stephen_Kleene
# /wiki/JSTOR
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/Donald_Knuth
# /wiki/ISBN
# /wiki/Donald_Knuth
# /wiki/Semantic_Scholar
# /wiki/Digital_object_identifier
# /wiki/A.A._Markov
# /wiki/Marvin_Minsky
# /wiki/ISBN
# /wiki/Emil_Post
# /wiki/JSTOR
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/JSTOR
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/Digital_object_identifier
# /wiki/ISBN
# /wiki/ISBN
# /wiki/ISBN
# /wiki/ISBN
# /wiki/Proceedings_of_the_London_Mathematical_Society
# /wiki/Digital_object_identifier
# /wiki/Digital_object_identifier
# /wiki/United_States_Patent_and_Trademark_Office
# /wiki/Wikcionario
# /wiki/Control_de_autoridades
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# /wiki/Biblioteca_Nacional_de_Francia
# /wiki/Gemeinsame_Normdatei
# /wiki/Library_of_Congress_Control_Number
# /wiki/Biblioteca_Nacional_de_la_Dieta
# /wiki/Biblioteca_Nacional_de_la_Rep%C3%BAblica_Checa
# /wiki/Biblioteca_Nacional_de_Israel
# /wiki/Art_%26_Architecture_Thesaurus
# /wiki/Enciclopedia_Brit%C3%A1nica
# /wiki/Enciclopedia_Treccani
# /wiki/Medical_Subject_Headings
# /wiki/Descriptores_en_Ciencias_de_la_Salud

# %%
# !pip install wikipedia-api
# !pip install pandas
# Out:
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.6.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from wikipedia-api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->wikipedia-api) (2023.7.22)
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.6.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import wikipediaapi
import time

# %%
# !pip install scrapy
# Out:
# Collecting scrapy
#   Downloading Scrapy-2.11.0-py2.py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.4/286.4 kB 3.7 MB/s eta 0:00:00
# Collecting Twisted<23.8.0,>=18.9.0 (from scrapy)
#   Downloading Twisted-22.10.0-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (41.0.5)
# Collecting cssselect>=0.9.1 (from scrapy)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting itemloaders>=1.0.1 (from scrapy)
#   Downloading itemloaders-1.1.0-py3-none-any.whl (11 kB)
# Collecting parsel>=1.5.0 (from scrapy)
#   Downloading parsel-1.8.1-py2.py3-none-any.whl (17 kB)
# Requirement already satisfied: pyOpenSSL>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from scrapy) (23.2.0)
# Collecting queuelib>=1.4.2 (from scrapy)
#   Downloading queuelib-1.6.2-py2.py3-none-any.whl (13 kB)
# Collecting service-identity>=18.1.0 (from scrapy)
#   Downloading service_identity-23.1.0-py3-none-any.whl (12 kB)
# Collecting w3lib>=1.17.0 (from scrapy)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting zope.interface>=5.1.0 (from scrapy)
#   Downloading zope.interface-6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (247 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.1/247.1 kB 17.0 MB/s eta 0:00:00
# Collecting protego>=0.1.15 (from scrapy)
#   Downloading Protego-0.3.0-py2.py3-none-any.whl (8.5 kB)
# Collecting itemadapter>=0.1.0 (from scrapy)
#   Downloading itemadapter-0.8.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from scrapy) (67.7.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from scrapy) (23.2)
# Collecting tldextract (from scrapy)
#   Downloading tldextract-5.0.1-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 14.0 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from scrapy) (4.9.3)
# Collecting PyDispatcher>=2.0.5 (from scrapy)
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->scrapy) (1.16.0)
# Collecting jmespath>=0.9.5 (from itemloaders>=1.0.1->scrapy)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (23.1.0)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.5.0)
# Requirement already satisfied: pyasn1-modules in /usr/local/lib/python3.10/dist-packages (from service-identity>=18.1.0->scrapy) (0.3.0)
# Collecting constantly>=15.1 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Collecting incremental>=21.3.0 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading incremental-22.10.0-py2.py3-none-any.whl (16 kB)
# Collecting Automat>=0.8.0 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading Automat-22.10.0-py2.py3-none-any.whl (26 kB)
# Collecting hyperlink>=17.1.1 (from Twisted<23.8.0,>=18.9.0->scrapy)
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.10/dist-packages (from Twisted<23.8.0,>=18.9.0->scrapy) (4.5.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.4)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (2.31.0)
# Collecting requests-file>=1.4 (from tldextract->scrapy)
#   Downloading requests_file-1.5.1-py2.py3-none-any.whl (3.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.10/dist-packages (from tldextract->scrapy) (3.12.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from Automat>=0.8.0->Twisted<23.8.0,>=18.9.0->scrapy) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->scrapy) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (3.3.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.1.0->tldextract->scrapy) (2023.7.22)
# Installing collected packages: PyDispatcher, incremental, zope.interface, w3lib, queuelib, protego, jmespath, itemadapter, hyperlink, cssselect, constantly, Automat, Twisted, requests-file, parsel, tldextract, service-identity, itemloaders, scrapy
# Successfully installed Automat-22.10.0 PyDispatcher-2.0.7 Twisted-22.10.0 constantly-23.10.4 cssselect-1.2.0 hyperlink-21.0.0 incremental-22.10.0 itemadapter-0.8.0 itemloaders-1.1.0 jmespath-1.0.1 parsel-1.8.1 protego-0.3.0 queuelib-1.6.2 requests-file-1.5.1 scrapy-2.11.0 service-identity-23.1.0 tldextract-5.0.1 w3lib-2.1.2 zope.interface-6.1

# %% [markdown]
# falta

# %%
import requests
from bs4 import BeautifulSoup
import json
import re

# Función para realizar web scraping recursivo
def scrape_wikipedia(url, max_depth, current_depth=0):
    if current_depth >= max_depth:
        return

    response = requests.get(url)
    if response.status_code == 200:
        page_content = response.text
        soup = BeautifulSoup(page_content, "html.parser")

        # Extraer el título de la página
        title = soup.find("h1").text

        # Extraer el contenido del artículo (párrafos)
        content_elements = soup.find_all('p')
        content = '\n'.join([p.text for p in content_elements])

        # Extraer el snippet (primer párrafo, 100 primeras palabras)
        snippet = " ".join(content_elements[0].text.split()[:100]) if content_elements else ""

        # Definir una expresión regular para filtrar los enlaces no deseados
        pattern = re.compile(r"/wiki/.*:|/wiki/Wiki")

        # Extraer los enlaces salientes
        outgoing_links = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("/wiki/") and not pattern.match(a["href"])]

        # Guardar los datos en un diccionario
        page_data = {
            "url": url,
            "titulo": title,
            "contenido": content,
            "snippet": snippet,
            "enlaces_salientes": outgoing_links
        }

        data.append(page_data)

       

        for link in outgoing_links:
            next_url = f"https://es.wikipedia.org{link}"
            scrape_wikipedia(next_url, max_depth, current_depth + 1)

# URL de la página de Wikipedia a la que deseas iniciar el web scraping
initial_url = "https://es.wikipedia.org/wiki/Algoritmo"

# Máxima profundidad de recursión (ajusta según tus necesidades)
max_depth = 2

# Crear una lista para almacenar los datos
data = []

# Iniciar el web scraping recursivo
scrape_wikipedia(initial_url, max_depth)

# Guardar el dataset como un archivo JSON
with open('wikipedia_dataset.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)

# %%
import re
from unicodedata import normalize

s = "Pingüino: Málãgà ês uñ̺ã cíudãd fantástica y èn Logroño me pica el... moñǫ̝̘̦̞̟̩̐̏̋͌́ͬ̚͡õ̪͓͍̦̓ơ̤̺̬̯͂̌͐͐͟o͎͈̳̠̼̫͂̊"


# -> NFD y eliminar diacríticos
s = re.sub(
        r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1", 
        normalize( "NFD", s), 0, re.I
    )

# -> NFC
s = normalize( 'NFC', s)

print( s )
# Out:
# Pinguino: Malaga es una ciudad fantastica y en Logroño me pica el... moñoooo

# %%
import requests
from bs4 import BeautifulSoup
from unicodedata import normalize
import json
import re

# Función para extraer el contenido de los párrafos
def extract_content(soup):
    content_data = []
    for paragraph in soup.find_all('p'):
        text = paragraph.get_text()

        # Eliminar tildes de las letras con tilde y mantener la letra ñ intacta
        text = re.sub(
            r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1",
            normalize("NFD", text), 0, re.I
        )
       
        text = text.replace("n\u0303", "ñ")  # Restaurar la letra "ñ"
        #print( text )
            
        # Eliminar comandos para fórmulas matemáticas (por ejemplo, {\displaystyle ...})
        text = re.sub(r'{\\[^}]+}', '', text)

        # Eliminar comandos y referencias (por ejemplo, [1], [2], [[Archivo:...])
        text = re.sub(r'\[\d+\]', '', text)  # Eliminar referencias numéricas
        text = re.sub(r'\[\[Archivo:[^\]]+\]\]', '', text)  # Eliminar referencias a archivos
        text = re.sub(r'\[\[[a-zA-Z0-9\s]+\]\]', '', text)  # Eliminar otras referencias en doble corchete

        # Eliminar caracteres no alfabéticos, convertir a minúsculas y eliminar saltos de línea adicionales
        text = re.sub(r'(\s*\n\s*)+', ' ', text).lower()

        content_data.append(text)

    return " ".join(content_data)

# Función para realizar web scraping recursivo
def scrape_wikipedia(url, max_depth, current_depth=0):
    if current_depth >= max_depth:
        return

    response = requests.get(url)
    if response.status_code == 200:
        page_content = response.text
        soup = BeautifulSoup(page_content, "html.parser")
        
        # Extraer el título de la página
        title = soup.find("h1").text

        # Extraer el contenido de títulos, subtítulos y párrafos
        content = extract_content(soup)
        content_elements = soup.find_all('p')
        # Extraer el snippet (primer párrafo, 200 primeras palabras)
        snippet = " ".join(content_elements[0].text.split()[:200]) if content_elements else ""
        
         # Definir una expresión regular para filtrar los enlaces no deseados
        pattern = re.compile(r"/wiki/.*:|/wiki/Wiki")

        # Extraer los enlaces salientes
        outgoing_links = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("/wiki/") and not pattern.match(a["href"])]

        # Guardar los datos en un diccionario
        page_data = {
            "url": url,
            "titulo": title,
            "contenido": content,
            "snippet": snippet,
            "enlaces_salientes": outgoing_links
        }

        data.append(page_data)

       

        for link in outgoing_links:
            next_url = f"https://es.wikipedia.org{link}"
            scrape_wikipedia(next_url, max_depth, current_depth + 1)

# URL de la página de Wikipedia a la que deseas iniciar el web scraping
initial_url = "https://es.wikipedia.org/wiki/Algoritmo"

# Máxima profundidad de recursión (ajusta según tus necesidades)
max_depth = 1

# Crear una lista para almacenar los datos
data = []

# Iniciar el web scraping recursivo
scrape_wikipedia(initial_url, max_depth)

# Guardar el dataset como un archivo JSON
with open('wikipedia_dataset.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)

# %%
import requests
from bs4 import BeautifulSoup
from unicodedata import normalize
import json
import re

# Función para extraer el contenido de los párrafos
def extract_content(soup):
    content_data = []
    for paragraph in soup.find_all('p'):
        text = paragraph.get_text()

        # Eliminar tildes de las letras con tilde y mantener la letra ñ intacta
        text = re.sub(
            r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1",
            normalize("NFD", text), 0, re.I
        )
        text = text.replace("n\u0303", "ñ")  # Restaurar la letra "ñ"

        # Eliminar comandos para fórmulas matemáticas (por ejemplo, {\displaystyle ...})
        text = re.sub(r'{\\[^}]+}', '', text)

        # Eliminar comandos y referencias (por ejemplo, [1], [2], [[Archivo:...])
        text = re.sub(r'\[\d+\]', '', text)  # Eliminar referencias numéricas
        text = re.sub(r'\[\[Archivo:[^\]]+\]\]', '', text)  # Eliminar referencias a archivos
        text = re.sub(r'\[\[[a-zA-Z0-9\s]+\]\]', '', text)  # Eliminar otras referencias en doble corchete

        # Eliminar caracteres no alfabéticos, convertir a minúsculas y eliminar saltos de línea adicionales
        text = re.sub(r'(\s*\n\s*)+', ' ', text).lower()

        content_data.append(text)

    return " ".join(content_data)

# Función para realizar web scraping recursivo
def scrape_wikipedia(url, max_pages, current_depth=0):
    if current_depth >= max_pages:
        return

    response = requests.get(url)
    if response.status_code == 200:
        page_content = response.text
        soup = BeautifulSoup(page_content, "html.parser")
        
        # Extraer el título de la página
        title = soup.find("h1").text

        # Extraer el contenido de títulos, subtítulos y párrafos
        content = extract_content(soup)
        content_elements = soup.find_all('p')
        # Extraer el snippet (primer párrafo, 200 primeras palabras)
        snippet = " ".join(content_elements[0].text.split()[:200]) if content_elements else ""
        
         # Definir una expresión regular para filtrar los enlaces no deseados
        pattern = re.compile(r"/wiki/.*:|/wiki/Wiki")

        # Extraer los enlaces salientes
        outgoing_links = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("/wiki/") and not pattern.match(a["href"])]

        # Guardar los datos en un diccionario
        page_data = {
            "url": url,
            "titulo": title,
            "contenido": content,
            "snippet": snippet,
            "enlaces_salientes": outgoing_links
        }

        data.append(page_data)

        for link in outgoing_links:
            next_url = f"https://es.wikipedia.org{link}"
            scrape_wikipedia(next_url, max_pages, current_depth + 1)

# URL de la página de Wikipedia a la que deseas iniciar el web scraping
initial_url = "https://es.wikipedia.org/wiki/Algoritmo"

# Máximo número de páginas a recopilar
max_pages = 2

# Crear una lista para almacenar los datos
data = []

# Iniciar el web scraping recursivo
scrape_wikipedia(initial_url, max_pages)

# Guardar el dataset como un archivo JSON
with open('wikipedia_dataset2.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)

# %%
import requests
from bs4 import BeautifulSoup
from unicodedata import normalize
import json
import re
import time

# Función para extraer el contenido de los párrafos
def extract_content(soup):
    content_data = []
    for paragraph in soup.find_all('p'):
        text = paragraph.get_text()

        # Eliminar tildes de las letras con tilde y mantener la letra ñ intacta
        text = re.sub(
            r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1",
            normalize("NFD", text), 0, re.I
        )
        text = text.replace("n\u0303", "ñ")  # Restaurar la letra "ñ"

        # Eliminar comandos para fórmulas matemáticas (por ejemplo, {\displaystyle ...})
        text = re.sub(r'{\\[^}]+}', '', text)

        # Eliminar comandos y referencias (por ejemplo, [1], [2], [[Archivo:...])
        text = re.sub(r'\[\d+\]', '', text)  # Eliminar referencias numéricas
        text = re.sub(r'\[\[Archivo:[^\]]+\]\]', '', text)  # Eliminar referencias a archivos
        text = re.sub(r'\[\[[a-zA-Z0-9\s]+\]\]', '', text)  # Eliminar otras referencias en doble corchete

        # Eliminar caracteres no alfabéticos, convertir a minúsculas y eliminar saltos de línea adicionales
        text = re.sub(r'(\s*\n\s*)+', ' ', text).lower()

        content_data.append(text)

    return " ".join(content_data)

# Función para realizar web scraping recursivo
def scrape_wikipedia(url, max_pages, current_depth=0):
    if current_depth >= max_pages:
        return

    start_time = time.time()  # Registrar el tiempo de inicio

    response = requests.get(url)
    if response.status_code == 200:
        page_content = response.text
        soup = BeautifulSoup(page_content, "html.parser")
        
        # Extraer el título de la página
        title = soup.find("h1").text

        # Extraer el contenido de títulos, subtítulos y párrafos
        content = extract_content(soup)
        content_elements = soup.find_all('p')
        # Extraer el snippet (primer párrafo, 200 primeras palabras)
        snippet = " ".join(content_elements[0].text.split()[:200]) if content_elements else ""
        
        # Definir una expresión regular para filtrar los enlaces no deseados
        pattern = re.compile(r"/wiki/.*:|/wiki/Wiki")

        # Extraer los enlaces salientes
        outgoing_links = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("/wiki/") and not pattern.match(a["href"])]

        # Imprimir el número de outgoing_links
        print(f'Página: {url}, outgoing_links: {len(outgoing_links)}')

        # Guardar los datos en un diccionario
        page_data = {
            "url": url,
            "titulo": title,
            "contenido": content,
            "snippet": snippet,
            "enlaces_salientes": outgoing_links
        }

        data.append(page_data)

        for link in outgoing_links:
            next_url = f"https://es.wikipedia.org{link}"
            scrape_wikipedia(next_url, max_pages, current_depth + 1)

    end_time = time.time()  # Registrar el tiempo de finalización
    elapsed_time = end_time - start_time
    print(f'Tiempo para la página : {elapsed_time:.2f} segundos')

# URL de la página de Wikipedia a la que deseas iniciar el web scraping
initial_url = "https://es.wikipedia.org/wiki/Algoritmo"

# Máximo número de páginas a recopilar
max_pages = 2

# Crear una lista para almacenar los datos
data = []

# Iniciar el web scraping recursivo
scrape_wikipedia(initial_url, max_pages)

# Guardar el dataset como un archivo JSON
with open('wikipedia_dataset2.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)
# Out:
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo: 0.61 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo: 0.60 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo: 0.61 segundos
# Página: https://es.wikipedia.org/wiki/Logaritmo, outgoing_links: 240
# Tiempo para la página https://es.wikipedia.org/wiki/Logaritmo: 0.69 segundos
# Página: https://es.wikipedia.org/wiki/Diagrama_de_flujo, outgoing_links: 73
# Tiempo para la página https://es.wikipedia.org/wiki/Diagrama_de_flujo: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Ada_Lovelace, outgoing_links: 143
# Tiempo para la página https://es.wikipedia.org/wiki/Ada_Lovelace: 0.64 segundos
# Página: https://es.wikipedia.org/wiki/Matem%C3%A1ticas, outgoing_links: 315
# Tiempo para la página https://es.wikipedia.org/wiki/Matem%C3%A1ticas: 0.70 segundos
# Página: https://es.wikipedia.org/wiki/L%C3%B3gica, outgoing_links: 559
# Tiempo para la página https://es.wikipedia.org/wiki/L%C3%B3gica: 0.69 segundos
# Página: https://es.wikipedia.org/wiki/Ciencias_de_la_computaci%C3%B3n, outgoing_links: 307
# Tiempo para la página https://es.wikipedia.org/wiki/Ciencias_de_la_computaci%C3%B3n: 0.63 segundos
# Página: https://es.wikipedia.org/wiki/Lat%C3%ADn_tard%C3%ADo, outgoing_links: 94
# Tiempo para la página https://es.wikipedia.org/wiki/Lat%C3%ADn_tard%C3%ADo: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/%C3%81rabe_cl%C3%A1sico, outgoing_links: 34
# Tiempo para la página https://es.wikipedia.org/wiki/%C3%81rabe_cl%C3%A1sico: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Empleador, outgoing_links: 37
# Tiempo para la página https://es.wikipedia.org/wiki/Empleador: 0.38 segundos
# Página: https://es.wikipedia.org/wiki/Matem%C3%A
 0.39 segundos
# Página: https://es.wikipedia.org/wiki/Dominio_de_definici%C3%B3n, outgoing_links: 27
# Tiempo para la página https://es.wikipedia.org/wiki/Dominio_de_definici%C3%B3n: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_computable, outgoing_links: 80
# Tiempo para la página https://es.wikipedia.org/wiki/Funci%C3%B3n_computable: 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Problema_de_la_parada, outgoing_links: 25
# Tiempo para la página https://es.wikipedia.org/wiki/Problema_de_la_parada: 0.49 segundos
# Página: https://es.wikipedia.org/wiki/An%C3%A1lisis_de_algoritmos, outgoing_links: 45
# Tiempo para la página https://es.wikipedia.org/wiki/An%C3%A1lisis_de_algoritmos: 0.49 segundos
# Página: https://es.wikipedia.org/wiki/Ciencias_de_la_computacion, outgoing_links: 307
# Tiempo para la página https://es.wikipedia.org/wiki/Ciencias_de_la_computacion: 0.64 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n, outgoing_links: 289
# Tiempo para la página https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n: 0.60 segundos
# Página: https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo, outgoing_links: 61
# Tiempo para la página https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo: 0.73 segundos
# Página: https://es.wikipedia.org/wiki/Lexico, outgoing_links: 14
# Tiempo para la página https://es.wikipedia.org/wiki/Lexico: 0.37 segundos
# Página: https://es.wikipedia.org/wiki/C%C3%B3digo_binario, outgoing_links: 25
# Tiempo para la página https://es.wikipedia.org/wiki/C%C3%B3digo_binario: 0.38 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_de_Euclides, outgoing_links: 78
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo_de_Euclides: 0.78 segundos
# Página: https://es.wikipedia.org/wiki/Conjunto, outgoing_links: 113
# Tiempo para la página https://es.wikipedia.org/wiki/Conjunto: 0.55 segundos
# Página: https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo, outgoing_links: 61
# Tiempo para la página https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo: 0.72 segundos
# Página: https://es.wikipedia.org/wiki/C%2B%2B, outgoing_links: 147
# Tiempo para la página https://es.wikipedia.org/wiki/C%2B%2B: 0.62 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_de_ordenamiento, outgoing_links: 79
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo_de_ordenamiento: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_de_b%C3%BAsqueda, outgoing_links: 27
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo_de_b%C3%BAsqueda: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_voraz, outgoing_links: 18
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo_voraz: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmos_paralelos, outgoing_links: 19
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmos_paralelos: 0.39 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_probabil%C3%ADstico, outgoing_links: 25
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo_probabil%C3%ADstico: 0.49 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_determin%C3%ADstico, outgoing_links: 32
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo_determin%C3%ADstico: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_no_determin%C3%ADstico, outgoing_links: 12
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo_no_determin%C3%ADstico: 0.39 segundos
# Página: https://es.wikipedia.org/wiki/Divide_y_vencer%C3%A1s, outgoing_links: 54
# Tiempo para la página https://es.wikipedia.org/wiki/Divide_y_vencer%C3%A1s: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Metaheur%C3%ADsticas, outgoing_links: 30
# Tiempo para la página https://es.wikipedia.org/wiki/Metaheur%C3%ADsticas: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Programaci%C3%B3n_din%C3%A1mica_(computaci%C3%B3n), outgoing_links: 40
# Tiempo para la página https://es.wikipedia.org/wiki/Programaci%C3%B3n_din%C3%A1mica_(computaci%C3%B3n): 0.49 segundos
# Página: https://es.wikipedia.org/wiki/Ramificaci%C3%B3n_y_acotaci%C3%B3n, outgoing_links: 31
# Tiempo para la página https://es.wikipedia.org/wiki/Ramificaci%C3%B3n_y_acotaci%C3%B3n: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Vuelta_atr%C3%A1s, outgoing_links: 20
# Tiempo para la página https://es.wikipedia.org/wiki/Vuelta_atr%C3%A1s: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Cota_inferior_asint%C3%B3tica, outgoing_links: 11
# Tiempo para la página https://es.wikipedia.org/wiki/Cota_inferior_asint%C3%B3tica: 0.38 segundos
# Página: https://es.wikipedia.org/wiki/Cota_ajustada_asint%C3%B3tica, outgoing_links: 11
# Tiempo para la página https://es.wikipedia.org/wiki/Cota_ajustada_asint%C3%B3tica: 0.39 segundos
# Página: https://es.wikipedia.org/wiki/Complejidad_computacional, outgoing_links: 90
# Tiempo para la página https://es.wikipedia.org/wiki/Complejidad_computacional: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Diagrama_de_flujo, outgoing_links: 73
# Tiempo para la página https://es.wikipedia.org/wiki/Diagrama_de_flujo: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Diagrama_Nassi-Shneiderman, outgoing_links: 18
# Tiempo para la página https://es.wikipedia.org/wiki/Diagrama_Nassi-Shneiderman: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A1quina_de_Turing, outgoing_links: 119
# Tiempo para la página https://es.wikipedia.org/wiki/M%C3%A1quina_de_Turing: 0.64 segundos
# Página: https://es.wikipedia.org/wiki/Ciencias_de_la_Computaci%C3%B3n, outgoing_links: 307
# Tiempo para la página https://es.wikipedia.org/wiki/Ciencias_de_la_Computaci%C3%B3n: 0.62 segundos
# Página: https://es.wikipedia.org/wiki/An%C3%A1lisis_de_algoritmos, outgoing_links: 45
# Tiempo para la página https://es.wikipedia.org/wiki/An%C3%A1lisis_de_algoritmos: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Complejidad_computacional, outgoing_links: 90
# Tiempo para la página https://es.wikipedia.org/wiki/Complejidad_computacional: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Gobierno_por_algoritmos, outgoing_links: 181
# Tiempo para la página https://es.wikipedia.org/wiki/Gobierno_por_algoritmos: 0.66 segundos
# Página: https://es.wikipedia.org/wiki/Inform%C3%A1tica, outgoing_links: 141
# Tiempo para la página https://es.wikipedia.org/wiki/Inform%C3%A1tica: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Inteligencia_artificial, outgoing_links: 499
# Tiempo para la página https://es.wikipedia.org/wiki/Inteligencia_artificial: 0.74 segundos
# Página: https://es.wikipedia.org/wiki/Investigaci%C3%B3n_operativa, outgoing_links: 185
# Tiempo para la página https://es.wikipedia.org/wiki/Investigaci%C3%B3n_operativa: 0.58 segundos
# Página: https://es.wikipedia.org/wiki/Matem%C3%A1ticas, outgoing_links: 315
# Tiempo para la página https://es.wikipedia.org/wiki/Matem%C3%A1ticas: 0.71 segundos
# Página: https://es.wikipedia.org/wiki/Programaci%C3%B3n, outgoing_links: 113
# Tiempo para la página https://es.wikipedia.org/wiki/Programaci%C3%B3n: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Thomas_H._Cormen, outgoing_links: 34
# Tiempo para la página https://es.wikipedia.org/wiki/Thomas_H._Cormen: 0.39 segundos
# Página: https://es.wikipedia.org/wiki/MIT_Press, outgoing_links: 40
# Tiempo para la página https://es.wikipedia.org/wiki/MIT_Press: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.54 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/ISSN, outgoing_links: 33
# Tiempo para la página https://es.wikipedia.org/wiki/ISSN: 0.49 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISSN, outgoing_links: 33
# Tiempo para la página https://es.wikipedia.org/wiki/ISSN: 0.49 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Rivest,_R._L., outgoing_links: 110
# Tiempo para la página https://es.wikipedia.org/wiki/Rivest,_R._L.: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/Gilles_Brassard, outgoing_links: 43
# Tiempo para la página https://es.wikipedia.org/wiki/Gilles_Brassard: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Knuth,_D._E, outgoing_links: 155
# Tiempo para la página https://es.wikipedia.org/wiki/Knuth,_D._E: 0.54 segundos
# Página: https://es.wikipedia.org/wiki/TeX, outgoing_links: 94
# Tiempo para la página https://es.wikipedia.org/wiki/TeX: 0.53 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n_Java, outgoing_links: 243
# Tiempo para la página https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n_Java: 0.66 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página https://es.wikipedia.org/wiki/JSTOR: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/George_Boolos, outgoing_links: 99
# Tiempo para la página https://es.wikipedia.org/wiki/George_Boolos: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Alonzo_Church, outgoing_links: 89
# Tiempo para la página https://es.wikipedia.org/wiki/Alonzo_Church: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página https://es.wikipedia.org/wiki/JSTOR: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Alonzo_Church, outgoing_links: 89
# Tiempo para la página https://es.wikipedia.org/wiki/Alonzo_Church: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página https://es.wikipedia.org/wiki/JSTOR: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página https://es.wikipedia.org/wiki/JSTOR: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.53 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/G%C3%B6del, outgoing_links: 255
# Tiempo para la página https://es.wikipedia.org/wiki/G%C3%B6del: 0.56 segundos
# Página: https://es.wikipedia.org/wiki/Alonzo_Church, outgoing_links: 89
# Tiempo para la
0.55 segundos
# Página: https://es.wikipedia.org/wiki/Semantic_Scholar, outgoing_links: 32
# Tiempo para la página https://es.wikipedia.org/wiki/Semantic_Scholar: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/A.A._Markov, outgoing_links: 72
# Tiempo para la página https://es.wikipedia.org/wiki/A.A._Markov: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Marvin_Minsky, outgoing_links: 93
# Tiempo para la página https://es.wikipedia.org/wiki/Marvin_Minsky: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Emil_Post, outgoing_links: 40
# Tiempo para la página https://es.wikipedia.org/wiki/Emil_Post: 0.39 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página https://es.wikipedia.org/wiki/JSTOR: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página https://es.wikipedia.org/wiki/JSTOR: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página https://es.wikipedia.org/wiki/ISBN: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Proceedings_of_the_London_Mathematical_Society, outgoing_links: 19
# Tiempo para la página https://es.wikipedia.org/wiki/Proceedings_of_the_London_Mathematical_Society: 0.38 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página https://es.wikipedia.org/wiki/Digital_object_identifier: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/United_States_Patent_and_Trademark_Office, outgoing_links: 77
# Tiempo para la página https://es.wikipedia.org/wiki/United_States_Patent_and_Trademark_Office: 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Wikcionario, outgoing_links: 55
# Tiempo para la página https://es.wikipedia.org/wiki/Wikcionario: 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Control_de_autoridades, outgoing_links: 7
# Tiempo para la página https://es.wikipedia.org/wiki/Control_de_autoridades: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Espa%C3%B1a, outgoing_links: 213
# Tiempo para la página https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Espa%C3%B1a: 0.70 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Francia, outgoing_links: 65
# Tiempo para la página https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Francia: 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Gemeinsame_Normdatei, outgoing_links: 23
# Tiempo para la página https://es.wikipedia.org/wiki/Gemeinsame_Normdatei: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Library_of_Congress_Control_Number, outgoing_links: 16
# Tiempo para la página https://es.wikipedia.org/wiki/Library_of_Congress_Control_Number: 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_la_Dieta, outgoing_links: 43
# Tiempo para la página https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_la_Dieta: 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_la_Rep%C3%BAblica_Checa, outgoing_links: 28
# Tiempo para la página https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_la_Rep%C3%BAblica_Checa: 0.48 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Israel, outgoing_links: 40
# Tiempo para la página https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Israel: 0.49 segundos
# Página: https://es.wikipedia.org/wiki/Art_%26_Architecture_Thesaurus, outgoing_links: 7
# Tiempo para la página https://es.wikipedia.org/wiki/Art_%26_Architecture_Thesaurus: 0.39 segundos
# Página: https://es.wikipedia.org/wiki/Enciclopedia_Brit%C3%A1nica, outgoing_links: 381
# Tiempo para la página https://es.wikipedia.org/wiki/Enciclopedia_Brit%C3%A1nica: 0.76 segundos
# Página: https://es.wikipedia.org/wiki/Enciclopedia_Treccani, outgoing_links: 90
# Tiempo para la página https://es.wikipedia.org/wiki/Enciclopedia_Treccani: 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Medical_Subject_Headings, outgoing_links: 29
# Tiempo para la página https://es.wikipedia.org/wiki/Medical_Subject_Headings: 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Descriptores_en_Ciencias_de_la_Salud, outgoing_links: 37
# Tiempo para la página https://es.wikipedia.org/wiki/Descriptores_en_Ciencias_de_la_Salud: 0.38 segundos
# Tiempo para la página https://es.wikipedia.org/wiki/Algoritmo: 114.12 segundos

# %% [markdown]
# Generación del archivo json data set con scrape

# %%
import requests
from bs4 import BeautifulSoup
from unicodedata import normalize
import json
import re
import time

# Función para extraer el contenido de los párrafos
def extract_content(soup):
    content_data = []
    for paragraph in soup.find_all('p'):
        text = paragraph.get_text()

        # Eliminar tildes de las letras con tilde y mantener la letra ñ intacta
        text = re.sub(
            r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1",
            normalize("NFD", text), 0, re.I
        )
        text = text.replace("n\u0303", "ñ")  # Restaurar la letra "ñ"

        # Eliminar comandos para fórmulas matemáticas (por ejemplo, {\displaystyle ...})
        text = re.sub(r'{\\[^}]+}', '', text)

        # Eliminar comandos y referencias (por ejemplo, [1], [2], [[Archivo:...])
        text = re.sub(r'\[\d+\]', '', text)  # Eliminar referencias numéricas
        text = re.sub(r'\[\[Archivo:[^\]]+\]\]', '', text)  # Eliminar referencias a archivos
        text = re.sub(r'\[\[[a-zA-Z0-9\s]+\]\]', '', text)  # Eliminar otras referencias en doble corchete

        # Eliminar caracteres no alfabéticos, convertir a minúsculas y eliminar saltos de línea adicionales
        text = re.sub(r'(\s*\n\s*)+', ' ', text).lower()

        content_data.append(text)

    return " ".join(content_data)

# Función para realizar web scraping recursivo
def scrape_wikipedia(url, max_pages, current_depth=0):
    if current_depth >= max_pages:
        return

    start_time = time.time()  # Registrar el tiempo de inicio

    response = requests.get(url)
    if response.status_code == 200:
        page_content = response.text
        soup = BeautifulSoup(page_content, "html.parser")
        
        # Extraer el título de la página
        title = soup.find("h1").text

        # Extraer el contenido de títulos, subtítulos y párrafos
        content = extract_content(soup)
        content_elements = soup.find_all('p')
        # Extraer el snippet (primer párrafo, 200 primeras palabras)
        snippet = " ".join(content_elements[0].text.split()[:200]) if content_elements else ""
        
        # Definir una expresión regular para filtrar los enlaces no deseados
        pattern = re.compile(r"/wiki/.*:|/wiki/Wiki")

        # Extraer los enlaces salientes
        outgoing_links = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("/wiki/") and not pattern.match(a["href"])]

        # Imprimir el número de outgoing_links
        print(f'Página: {url}, outgoing_links: {len(outgoing_links)}')

        # Guardar los datos en un diccionario
        page_data = {
            "url": url,
            "titulo": title,
            "contenido": content,
            "snippet": snippet,
            "enlaces_salientes": outgoing_links
        }

        data.append(page_data)

        for link in outgoing_links:
            next_url = f"https://es.wikipedia.org{link}"
            scrape_wikipedia(next_url, max_pages, current_depth + 1)

    end_time = time.time()  # Registrar el tiempo de finalización
    elapsed_time = end_time - start_time
    print(f'Tiempo para la página : {elapsed_time:.2f} segundos')

# URL de la página de Wikipedia a la que deseas iniciar el web scraping
initial_url = "https://es.wikipedia.org/wiki/Algoritmo"

# Máximo número de páginas a recopilar
max_pages = 3

# Crear una lista para almacenar los datos
data = []

# Iniciar el web scraping recursivo
scrape_wikipedia(initial_url, max_pages)

# Guardar el dataset como un archivo JSON
with open('wikipedia_dataset3.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)
# Out:
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Tiempo para la página : 0.60 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Tiempo para la página : 0.60 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# Tiempo para la página : 0.59 segundos
# Página: https://es.wikipedia.org/wiki/Logaritmo, outgoing_links: 240
# Tiempo para la página : 0.69 segundos
# Página: https://es.wikipedia.org/wiki/Diagrama_de_flujo, outgoing_links: 73
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Ada_Lovelace, outgoing_links: 143
# Tiempo para la página : 0.61 segundos
# Página: https://es.wikipedia.org/wiki/Matem%C3%A1ticas, outgoing_links: 315
# Tiempo para la página : 0.70 segundos
# Página: https://es.wikipedia.org/wiki/L%C3%B3gica, outgoing_links: 559
# Tiempo para la página : 0.68 segundos
# Página: https://es.wikipedia.org/wiki/Ciencias_de_la_computaci%C3%B3n, outgoing_links: 307
# Tiempo para la página : 0.62 segundos
# Página: https://es.wikipedia.org/wiki
# Tiempo para la página : 0.38 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Jean_van_Heijenoort, outgoing_links: 43
# Tiempo para la página : 0.39 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.53 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Andrew_Hodges, outgoing_links: 38
# Tiempo para la página : 0.53 segundos
# Página: https://es.wikipedia.org/wiki/Simon_and_Schuster, outgoing_links: 79
# Tiempo para la página : 0.48 segundos
# Página: https://es.wikipedia.org/wiki/Bibcode, outgoing_links: 13
# Tiempo para la página : 0.38 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.53 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Stephen_Kleene, outgoing_links: 64
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Semantic_Scholar, outgoing_links: 32
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Stephen_Kleene, outgoing_links: 64
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.49 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Donald_Knuth, outgoing_links: 155
# Tiempo para la página : 0.54 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Donald_Knuth, outgoing_links: 155
# Tiempo para la página : 0.54 segundos
# Página: https://es.wikipedia.org/wiki/Semantic_Scholar, outgoing_links: 32
# Tiempo para la página : 0.45 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/A.A._Markov, outgoing_links: 72
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Marvin_Minsky, outgoing_links: 93
# Tiempo para la página : 0.48 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Emil_Post, outgoing_links: 40
# Tiempo para la página : 0.49 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.48 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 0.48 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.53 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Proceedings_of_the_London_Mathematical_Society, outgoing_links: 19
# Tiempo para la página : 0.37 segundos
# ...
# Tiempo para la página : 0.39 segundos
# Página: https://es.wikipedia.org/wiki/Entscheidungsproblem, outgoing_links: 37
# Tiempo para la página : 0.38 segundos
# Página: https://es.wikipedia.org/wiki/Problema_de_decisi%C3%B3n, outgoing_links: 32
# Tiempo para la página : 0.39 segundos
# Página: https://es.wikipedia.org/wiki/Idioma_alem%C3%A1n, outgoing_links: 539
# Tiempo para la página : 0.71 segundos
# Página: https://es.wikipedia.org/wiki/L%C3%B3gica_de_primer_orden, outgoing_links: 169
# Tiempo para la página : 0.57 segundos
# Página: https://es.wikipedia.org/wiki/Alonzo_Church, outgoing_links: 89
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Alan_Turing, outgoing_links: 355
# Tiempo para la página : 0.66 segundos
# Página: https://es.wikipedia.org/wiki/Tesis_de_Church-Turing, outgoing_links: 35
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Problema_de_la_parada, outgoing_links: 25
# Tiempo para la página : 0.48 segundos
# Página: https://es.wikipedia.org/wiki/N%C3%BAmero_computable, outgoing_links: 52
# Tiempo para la página : 0.49 segundos
# Página: https://es.wikipedia.org/wiki/N%C3%BAmero_real, outgoing_links: 163
# Tiempo para la página : 0.68 segundos
# Página: https://es.wikipedia.org/wiki/Constante_de_Chaitin, outgoing_links: 27
# Tiempo para la página : 0.38 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_formal, outgoing_links: 61
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/Gram%C3%A1tica_formal, outgoing_links: 76
# Tiempo para la página : 0.52 segundos
# Página: https://es.wikipedia.org/wiki/C%C3%A1lculo_Lambda, outgoing_links: 100
# Tiempo para la página : 0.55 segundos
# Página: https://es.wikipedia.org/wiki/Tesis_de_Church-Turing, outgoing_links: 35
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Ordenador, outgoing_links: 362
# Tiempo para la página : 0.59 segundos
# Página: https://es.wikipedia.org/wiki/Arquitectura_de_von_Neumann, outgoing_links: 149
# Tiempo para la página : 0.54 segundos
# Página: https://es.wikipedia.org/wiki/Computaci%C3%B3n_cu%C3%A1ntica, outgoing_links: 158
# Tiempo para la página : 0.57 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n, outgoing_links: 289
# Tiempo para la página : 0.58 segundos
# Página: https://es.wikipedia.org/wiki/Turing_completo, outgoing_links: 32
# Tiempo para la página : 0.40 segundos
# Página: https://es.wikipedia.org/wiki/Turmite, outgoing_links: 20
# Tiempo para la página : 0.53 segundos
# Página: https://es.wikipedia.org/wiki/Aut%C3%B3mata_finito, outgoing_links: 135
# Tiempo para la página : 0.58 segundos
# Página: https://es.wikipedia.org/wiki/Gram%C3%A1tica_formal, outgoing_links: 76
# Tiempo para la página : 0.67 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A1quina_de_Post, outgoing_links: 10
# Tiempo para la página : 0.37 segundos
# Página: https://es.wikipedia.org/wiki/C%C3%A1lculo_Lambda, outgoing_links: 100
# Tiempo para la página : 0.55 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_recursiva, outgoing_links: 25
# Tiempo para la página : 1.39 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n, outgoing_links: 289
# Tiempo para la página : 0.60 segundos
# Página: https://es.wikipedia.org/wiki/Aut%C3%B3mata_celular, outgoing_links: 69
# Tiempo para la página : 0.50 segundos
# Página: https://es.wikipedia.org/wiki/Juego_de_la_vida, outgoing_links: 65
# Tiempo para la página : 0.50 segundos
# Página: https://es.wikipedia.org/wiki/John_Horton_Conway, outgoing_links: 196
# Tiempo para la página : 0.57 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A1quina_de_Turing, outgoing_links: 119
# Tiempo para la página : 0.68 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A1quina_de_Turing_probabil%C3%ADstica, outgoing_links: 17
# Tiempo para la página : 0.37 segundos
# Página: https://es.wikipedia.org/wiki/Computaci%C3%B3n_cu%C3%A1ntica, outgoing_links: 158
# Tiempo para la página : 0.56 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A1quina_or%C3%A1culo, outgoing_links: 26
# Tiempo para la página : 0.38 segundos
# Página: https://es.wikipedia.org/wiki/Caja_negra_(sistemas), outgoing_links: 25
# Tiempo para la página : 0.46 segundos
# Página: https://es.wikipedia.org/wiki/Conjunto_de_Mandelbrot, outgoing_links: 81
# Tiempo para la página : 0.56 segundos
# Página: https://es.wikipedia.org/wiki/Cambridge_University_Press, outgoing_links: 50
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/
segundos
# Página: https://es.wikipedia.org/wiki/C%C3%A1lculo, outgoing_links: 266
# Tiempo para la página : 0.55 segundos
# Página: https://es.wikipedia.org/wiki/Ren%C3%A9_Descartes, outgoing_links: 620
# Tiempo para la página : 0.79 segundos
# Página: https://es.wikipedia.org/wiki/Isaac_Newton, outgoing_links: 359
# Tiempo para la página : 0.66 segundos
# Página: https://es.wikipedia.org/wiki/Gottfried_Leibniz, outgoing_links: 719
# Tiempo para la página : 0.76 segundos
# Página: https://es.wikipedia.org/wiki/Alexis_Claude_Clairaut, outgoing_links: 74
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Leonhard_Euler, outgoing_links: 378
# Tiempo para la página : 0.78 segundos
# Página: https://es.wikipedia.org/wiki/Peter_Gustav_Lejeune_Dirichlet, outgoing_links: 140
# Tiempo para la página : 0.51 segundos
# Página: https://es.wikipedia.org/wiki/F%C3%ADsica, outgoing_links: 994
# Tiempo para la página : 0.83 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_continua, outgoing_links: 75
# Tiempo para la página : 0.61 segundos
# Página: https://es.wikipedia.org/wiki/Derivada, outgoing_links: 153
# Tiempo para la página : 0.69 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_de_Weierstrass, outgoing_links: 23
# Tiempo para la página : 0.47 segundos
# Página: https://es.wikipedia.org/wiki/Julius_Wilhelm_Richard_Dedekind, outgoing_links: 105
# Tiempo para la página : 0.49 segundos

# %% [markdown]
# Evitar links repetidos:

# %%
import requests
from bs4 import BeautifulSoup
from unicodedata import normalize
import json
import re
import time

# Crear un conjunto para mantener un registro de las URLs visitadas
visited_urls = set()

# Función para extraer el contenido de los párrafos
def extract_content(soup):
    content_data = []
    for paragraph in soup.find_all('p'):
        text = paragraph.get_text()

        # Eliminar tildes de las letras con tilde y mantener la letra ñ intacta
        text = re.sub(
            r"([^n\u0300-\u036f]|n(?!\u0303(?![\u0300-\u036f])))[\u0300-\u036f]+", r"\1",
            normalize("NFD", text), 0, re.I
        )
        text = text.replace("n\u0303", "ñ")  # Restaurar la letra "ñ"

        # Eliminar comandos para fórmulas matemáticas (por ejemplo, {\displaystyle ...})
        text = re.sub(r'{\\[^}]+}', '', text)

        # Eliminar comandos y referencias (por ejemplo, [1], [2], [[Archivo:...])
        text = re.sub(r'\[\d+\]', '', text)  # Eliminar referencias numéricas
        text = re.sub(r'\[\[Archivo:[^\]]+\]\]', '', text)  # Eliminar referencias a archivos
        text = re.sub(r'\[\[[a-zA-Z0-9\s]+\]\]', '', text)  # Eliminar otras referencias en doble corchete

        # Eliminar caracteres no alfabéticos, convertir a minúsculas y eliminar saltos de línea adicionales
        text = re.sub(r'(\s*\n\s*)+', ' ', text).lower()

        content_data.append(text)

    return " ".join(content_data)

# Función para realizar web scraping recursivo
def scrape_wikipedia(url, max_pages, current_depth=0):
    if current_depth >= max_pages:
        return

    start_time = time.time()  # Registrar el tiempo de inicio
    
    # Verificar si la URL ya ha sido visitada
    if url in visited_urls:
        print(f'URL repetida: {url}')
        return

    visited_urls.add(url)
    
    response = requests.get(url)
    if response.status_code == 200:
        page_content = response.text
        soup = BeautifulSoup(page_content, "html.parser")
        
        # Extraer el título de la página
        title = soup.find("h1").text

        # Extraer el contenido de títulos, subtítulos y párrafos
        content = extract_content(soup)
        content_elements = soup.find_all('p')
        # Extraer el snippet (primer párrafo, 200 primeras palabras)
        snippet = " ".join(content_elements[0].text.split()[:200]) if content_elements else ""
        
        # Definir una expresión regular para filtrar los enlaces no deseados
        pattern = re.compile(r"/wiki/.*:|/wiki/Wiki")

        # Extraer los enlaces salientes
        outgoing_links = [a["href"] for a in soup.find_all("a", href=True) if a["href"].startswith("/wiki/") and not pattern.match(a["href"])]

        # Imprimir el número de outgoing_links
        print(f'Página: {url}, outgoing_links: {len(outgoing_links)}')

        # Guardar los datos en un diccionario
        page_data = {
            "url": url,
            "titulo": title,
            "contenido": content,
            "snippet": snippet,
            "enlaces_salientes": outgoing_links
        }

        data.append(page_data)

        for link in outgoing_links:
            next_url = f"https://es.wikipedia.org{link}"
            scrape_wikipedia(next_url, max_pages, current_depth + 1)

    end_time = time.time()  # Registrar el tiempo de finalización
    elapsed_time = end_time - start_time
    print(f'Tiempo para la página : {elapsed_time:.2f} segundos')

# URL de la página de Wikipedia a la que deseas iniciar el web scraping
initial_url = "https://es.wikipedia.org/wiki/Algoritmo"

# Máximo número de páginas a recopilar
max_pages = 2

# Crear una lista para almacenar los datos
data = []

# Iniciar el web scraping recursivo
scrape_wikipedia(initial_url, max_pages)

# Guardar el dataset como un archivo JSON
with open('wikipedia_dataset2_S.json', 'w', encoding='utf-8') as json_file:
    json.dump(data, json_file, ensure_ascii=False, indent=4)
# Out:
# Página: https://es.wikipedia.org/wiki/Algoritmo, outgoing_links: 217
# URL repetida: https://es.wikipedia.org/wiki/Algoritmo
# URL repetida: https://es.wikipedia.org/wiki/Algoritmo
# URL repetida: https://es.wikipedia.org/wiki/Algoritmo
# Página: https://es.wikipedia.org/wiki/Logaritmo, outgoing_links: 240
# Tiempo para la página : 2.09 segundos
# Página: https://es.wikipedia.org/wiki/Diagrama_de_flujo, outgoing_links: 73
# Tiempo para la página : 1.79 segundos
# Página: https://es.wikipedia.org/wiki/Ada_Lovelace, outgoing_links: 143
# Tiempo para la página : 1.90 segundos
# Página: https://es.wikipedia.org/wiki/Matem%C3%A1ticas, outgoing_links: 315
# Tiempo para la página : 2.14 segundos
# Página: https://es.wikipedia.org/wiki/L%C3%B3gica, outgoing_links: 559
# Tiempo para la página : 2.14 segundos
# Página: https://es.wikipedia.org/wiki/Ciencias_de_la_computaci%C3%B3n, outgoing_links: 307
# Tiempo para la página : 2.02 segundos
# Página: https://es.wikipedia.org/wiki/Lat%C3%ADn_tard%C3%ADo, outgoing_links: 94
# Tiempo para la página : 1.56 segundos
# Página: https://es.wikipedia.org/wiki/%C3%81rabe_cl%C3%A1sico, outgoing_links: 34
# Tiempo para la página : 1.56 segundos
# Página: https://es.wikipedia.org/wiki/Empleador, outgoing_links: 37
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/Matem%C3%A1tica, outgoing_links: 315
# Tiempo para la página : 2.05 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_de_multiplicaci%C3%B3n, outgoing_links: 20
# Tiempo para la página : 1.64 segundos
# Página: https://es.wikipedia.org/wiki/C%C3%A1lculo, outgoing_links: 266
# Tiempo para la página : 1.71 segundos
# Página: https://es.wikipedia.org/wiki/Divisi%C3%B3n_(matem%C3%A1ticas), outgoing_links: 126
# Tiempo para la página : 1.75 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_de_Euclides, outgoing_links: 78
# Tiempo para la página : 3.01 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A1ximo_com%C3%BAn_divisor, outgoing_links: 34
# Tiempo para la página : 1.61 segundos
# Página: https://es.wikipedia.org/wiki/N%C3%BAmeros_enteros, outgoing_links: 109
# Tiempo para la página : 1.72 segundos
# Página: https://es.wikipedia.org/wiki/Eliminaci%C3%B3n_de_Gauss-Jordan, outgoing_links: 65
# Tiempo para la página : 1.71 segundos
# Página: https://es.wikipedia.org/wiki/Sistema_de_ecuaciones_lineales, outgoing_links: 66
# Tiempo para la página : 1.68 segundos
# URL repetida: https://es.wikipedia.org/wiki/C%C3%A1lculo
# Página: https://es.wikipedia.org/wiki/Problema_abstracto, outgoing_links: 19
# Tiempo para la página : 1.56 segundos
# Página: https://es.wikipedia.org/wiki/Criba_de_Erat%C3%B3stenes, outgoing_links: 24
# Tiempo para la página : 1.52 segundos
# Página: https://es.wikipedia.org/wiki/Alonzo_Church, outgoing_links: 89
# Tiempo para la página : 1.62 segundos
# Página: https://es.wikipedia.org/wiki/C%C3%A1lculo_lambda, outgoing_links: 100
# Tiempo para la página : 1.65 segundos
# Página: https://es.wikipedia.org/wiki/Alan_Turing, outgoing_links: 355
# Tiempo para la página : 2.09 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A1quina_de_Turing, outgoing_links: 119
# Tiempo para la página : 1.87 segundos
# Página: https://es.wikipedia.org/wiki/Grafo, outgoing_links: 112
# Tiempo para la página : 1.53 segundos
# Página: https://es.wikipedia.org/wiki/Estructura_de_datos, outgoing_links: 59
# Tiempo para la página : 1.54 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_paralelo, outgoing_links: 19
# Tiempo para la página : 1.22 segundos
# Página: https://es.wikipedia.org/wiki/L%C3%B3gica_matem%C3%A1tica, outgoing_links: 399
# Tiempo para la página : 1.77 segundos
# Página: https://es.wikipedia.org/wiki/M%C3%A9todo_de_Newton, outgoing_links: 51
# Tiempo para la página : 1.56 segundos
# URL repetida: https://es.wikipedia.org/wiki/Eliminaci%C3%B3n_de_Gauss-Jordan
# Página: https://es.wikipedia.org/wiki/Tesis_de_Church-Turing, outgoing_links: 35
# Tiempo para la página : 1.86 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_natural, outgoing_links: 68
# Tiempo para la página : 1.58 segundos
# Página: https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo, outgoing_links: 61
# Tiempo para la página : 1.98 segundos
# Página: https://es.wikipedia.org/wiki/Diagramas_de_flujo, outgoing_links: 73
# Tiempo para la página : 1.94 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n, outgoing_links: 289
# Tiempo para la página : 1.65 segundos
# Página: https://es.wikipedia.org/wiki/Teorema, outgoing_links: 121
# Tiempo para la página : 1.73 segundos
# URL repetida: https://es.wikipedia.org/wiki/Diagrama_de_flujo
# URL repetida: https://es.wikipedia.org/wiki/Diagrama_de_flujo
# Página: https://es.wikipedia.org/wiki/Organizaci%C3%B3n_Internacional_para_la_Estandarizaci%C3%B3n, outgoing_links: 79
# Tiempo para la página : 1.84 segundos
# URL repetida: https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo
# Página: https://es.wikipedia.org/wiki/Teor%C3%ADa_de_aut%C3%B3matas, outgoing_links: 43
# Tiempo para la página : 1.49 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_recursiva, outgoing_links: 25
# Tiempo para la página : 1.32 segundos
# URL repetida: https://es.wikipedia.org/wiki/M%C3%A1quina_de_Turing
# Página: https://es.wikipedia.org/wiki/M%C3%A1quina_de_registro, outgoing_links: 28
# Tiempo para la página : 1.33 segundos
# URL repetida: https://es.wikipedia.org/wiki/Funci%C3%B3n_recursiva
# Página: https://es.wikipedia.org/wiki/Lenguaje_m%C3%A1quina, outgoing_links: 32
# Tiempo para la página : 1.44 segundos
# Página: https://es.wikipedia.org/wiki/Programa_(computaci%C3%B3n), outgoing_links: 168
# Tiempo para la página : 1.55 segundos
# Página: https://es.wikipedia.org/wiki/Red_neuronal_artificial, outgoing_links: 304
# Tiempo para la página : 1.93 segundos
# URL repetida: https://es.wikipedia.org/wiki/Algoritmo_de_multiplicaci%C3%B3n
# URL repetida: https://es.wikipedia.org/wiki/Algoritmo_de_Euclides
# URL repetida: https://es.wikipedia.org/wiki/Criba_de_Erat%C3%B3stenes
# Página: https://es.wikipedia.org/wiki/Formas_de_resolver_la_ra%C3%ADz_cuadrada, outgoing_links: 37
# Tiempo para la página : 1.65 segundos
# Página: https://es.wikipedia.org/wiki/Teor%C3%ADa_de_la_computabilidad, outgoing_links: 154
# Tiempo para la página : 1.54 segundos
# Página: https://es.wikipedia.org/wiki/Camino_hamiltoniano, outgoing_links: 26
# Tiempo para la página : 1.67 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_matem%C3%A1tica, outgoing_links: 169
# Tiempo para la página : 1.87 segundos
# URL repetida: https://es.wikipedia.org/wiki/Problema_abstracto
# Página: https://es.wikipedia.org/wiki/Bit, outgoing_links: 99
# Tiempo para la página : 1.63 segundos
# Página: https://es.wikipedia.org/wiki/N%C3%BAmero_natural, outgoing_links: 136
# Tiempo para la página : 1.71 segundos
# Página: https://es.wikipedia.org/wiki/Sistema_binario, outgoing_links: 93
# Tiempo para la página : 1.74 segundos
# Página: https://es.wikipedia.org/wiki/Teor%C3%ADa_de_c%C3%B3digos, outgoing_links: 98
# Tiempo para la página : 1.74 segundos
# Página: https://es.wikipedia.org/wiki/Bucle_infinito, outgoing_links: 14
# Tiempo para la página : 1.71 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_parcial, outgoing_links: 19
# Tiempo para la página : 1.32 segundos
# Página: https://es.wikipedia.org/wiki/Dominio_de_definici%C3%B3n, outgoing_links: 27
# Tiempo para la página : 1.55 segundos
# Página: https://es.wikipedia.org/wiki/Funci%C3%B3n_computable, outgoing_links: 80
# Tiempo para la página : 1.56 segundos
# Página: https://es.wikipedia.org/wiki/Problema_de_la_parada, outgoing_links: 25
# Tiempo para la página : 1.79 segundos
# Página: https://es.wikipedia.org/wiki/An%C3%A1lisis_de_algoritmos, outgoing_links: 45
# Tiempo para la página : 1.51 segundos
# Página: https://es.wikipedia.org/wiki/Ciencias_de_la_computacion, outgoing_links: 307
# Tiempo para la página : 1.80 segundos
# URL repetida: https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n
# URL repetida: https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo
# Página: https://es.wikipedia.org/wiki/Lexico, outgoing_links: 14
# Tiempo para la página : 1.28 segundos
# Página: https://es.wikipedia.org/wiki/C%C3%B3digo_binario, outgoing_links: 25
# Tiempo para la página : 1.45 segundos
# URL repetida: https://es.wikipedia.org/wiki/Algoritmo_de_Euclides
# Página: https://es.wikipedia.org/wiki/Conjunto, outgoing_links: 113
# Tiempo para la página : 1.41 segundos
# URL repetida: https://es.wikipedia.org/wiki/Pseudoc%C3%B3digo
# Página: https://es.wikipedia.org/wiki/C%2B%2B, outgoing_links: 147
# Tiempo para la página : 1.75 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_de_ordenamiento, outgoing_links: 79
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_de_b%C3%BAsqueda, outgoing_links: 27
# Tiempo para la página : 1.61 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_voraz, outgoing_links: 18
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmos_paralelos, outgoing_links: 19
# Tiempo para la página : 1.44 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_probabil%C3%ADstico, outgoing_links: 25
# Tiempo para la página : 1.52 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_determin%C3%ADstico, outgoing_links: 32
# Tiempo para la página : 1.51 segundos
# Página: https://es.wikipedia.org/wiki/Algoritmo_no_determin%C3%ADstico, outgoing_links: 12
# Tiempo para la página : 1.52 segundos
# Página: https://es.wikipedia.org/wiki/Divide_y_vencer%C3%A1s, outgoing_links: 54
# Tiempo para la página : 1.55 segundos
# Página: https://es.wikipedia.org/wiki/Metaheur%C3%ADsticas, outgoing_links: 30
# Tiempo para la página : 1.43 segundos
# Página: https://es.wikipedia.org/wiki/Programaci%C3%B3n_din%C3%A1mica_(computaci%C3%B3n), outgoing_links: 40
# Tiempo para la página : 1.69 segundos
# Página: https://es.wikipedia.org/wiki/Ramificaci%C3%B3n_y_acotaci%C3%B3n, outgoing_links: 31
# Tiempo para la página : 1.73 segundos
# Página: https://es.wikipedia.org/wiki/Vuelta_atr%C3%A1s, outgoing_links: 20
# Tiempo para la página : 1.77 segundos
# Página: https://es.wikipedia.org/wiki/Cota_inferior_asint%C3%B3tica, outgoing_links: 11
# Tiempo para la página : 1.68 segundos
# Página: https://es.wikipedia.org/wiki/Cota_ajustada_asint%C3%B3tica, outgoing_links: 11
# Tiempo para la página : 1.52 segundos
# Página: https://es.wikipedia.org/wiki/Complejidad_computacional, outgoing_links: 90
# Tiempo para la página : 1.60 segundos
# URL repetida: https://es.wikipedia.org/wiki/Diagrama_de_flujo
# Página: https://es.wikipedia.org/wiki/Diagrama_Nassi-Shneiderman, outgoing_links: 18
# Tiempo para la página : 1.70 segundos
# URL repetida: https://es.wikipedia.org/wiki/M%C3%A1quina_de_Turing
# Página: https://es.wikipedia.org/wiki/Ciencias_de_la_Computaci%C3%B3n, outgoing_links: 307
# Tiempo para la página : 2.09 segundos
# URL repetida: https://es.wikipedia.org/wiki/An%C3%A1lisis_de_algoritmos
# URL repetida: https://es.wikipedia.org/wiki/Complejidad_computacional
# Página: https://es.wikipedia.org/wiki/Gobierno_por_algoritmos, outgoing_links: 181
# Tiempo para la página : 2.26 segundos
# Página: https://es.wikipedia.org/wiki/Inform%C3%A1tica, outgoing_links: 141
# Tiempo para la página : 1.91 segundos
# Página: https://es.wikipedia.org/wiki/Inteligencia_artificial, outgoing_links: 494
# Tiempo para la página : 2.22 segundos
# Página: https://es.wikipedia.org/wiki/Investigaci%C3%B3n_operativa, outgoing_links: 185
# Tiempo para la página : 2.11 segundos
# URL repetida: https://es.wikipedia.org/wiki/Matem%C3%A1ticas
# Página: https://es.wikipedia.org/wiki/Programaci%C3%B3n, outgoing_links: 113
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/ISBN, outgoing_links: 46
# Tiempo para la página : 1.73 segundos
# Página: https://es.wikipedia.org/wiki/Thomas_H._Cormen, outgoing_links: 34
# Tiempo para la página : 1.36 segundos
# Página: https://es.wikipedia.org/wiki/MIT_Press, outgoing_links: 40
# Tiempo para la página : 1.48 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/ISSN, outgoing_links: 33
# Tiempo para la página : 1.56 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISSN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/Rivest,_R._L., outgoing_links: 110
# Tiempo para la página : 1.63 segundos
# Página: https://es.wikipedia.org/wiki/Gilles_Brassard, outgoing_links: 43
# Tiempo para la página : 1.76 segundos
# Página: https://es.wikipedia.org/wiki/Knuth,_D._E, outgoing_links: 155
# Tiempo para la página : 1.62 segundos
# Página: https://es.wikipedia.org/wiki/TeX, outgoing_links: 94
# Tiempo para la página : 1.48 segundos
# Página: https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n_Java, outgoing_links: 243
# Tiempo para la página : 2.17 segundos
# Página: https://es.wikipedia.org/wiki/JSTOR, outgoing_links: 28
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/Digital_object_identifier, outgoing_links: 10
# Tiempo para la página : 1.53 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/George_Boolos, outgoing_links: 99
# Tiempo para la página : 1.50 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/Alonzo_Church
# URL repetida: https://es.wikipedia.org/wiki/JSTOR
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/Alonzo_Church
# URL repetida: https://es.wikipedia.org/wiki/JSTOR
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/JSTOR
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/G%C3%B6del, outgoing_links: 255
# Tiempo para la página : 1.67 segundos
# URL repetida: https://es.wikipedia.org/wiki/Alonzo_Church
# URL repetida: https://es.wikipedia.org/wiki/Alan_Turing
# Página: https://es.wikipedia.org/wiki/Emil_Post, outgoing_links: 40
# Tiempo para la página : 1.49 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/Gottfried_Leibniz, outgoing_links: 719
# Tiempo para la página : 2.11 segundos
# Página: https://es.wikipedia.org/wiki/George_Boole, outgoing_links: 142
# Tiempo para la página : 2.20 segundos
# Página: https://es.wikipedia.org/wiki/Gottlob_Frege, outgoing_links: 206
# Tiempo para la página : 1.70 segundos
# Página: https://es.wikipedia.org/wiki/Georg_Cantor, outgoing_links: 153
# Tiempo para la página : 1.79 segundos
# Página: https://es.wikipedia.org/wiki/David_Hilbert, outgoing_links: 239
# Tiempo para la página : 1.75 segundos
# Página: https://es.wikipedia.org/wiki/John_von_Neumann, outgoing_links: 365
# Tiempo para la página : 2.10 segundos
# Página: https://es.wikipedia.org/wiki/Joseph-Marie_Jacquard, outgoing_links: 53
# Tiempo para la página : 1.94 segundos
# Página: https://es.wikipedia.org/wiki/Babbage, outgoing_links: 167
# Tiempo para la página : 1.68 segundos
# URL repetida: https://es.wikipedia.org/wiki/Ada_Lovelace
# Página: https://es.wikipedia.org/wiki/Claude_Shannon, outgoing_links: 147
# Tiempo para la página : 1.65 segundos
# Página: https://es.wikipedia.org/wiki/Howard_Aiken, outgoing_links: 98
# Tiempo para la página : 1.65 segundos
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# Página: https://es.wikipedia.org/wiki/Bibcode, outgoing_links: 13
# Tiempo para la página : 1.75 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/Jean_van_Heijenoort, outgoing_links: 43
# Tiempo para la página : 1.83 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/Andrew_Hodges, outgoing_links: 38
# Tiempo para la página : 1.43 segundos
# Página: https://es.wikipedia.org/wiki/Simon_and_Schuster, outgoing_links: 79
# Tiempo para la página : 1.49 segundos
# URL repetida: https://es.wikipedia.org/wiki/Bibcode
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/Stephen_Kleene, outgoing_links: 64
# Tiempo para la página : 1.57 segundos
# Página: https://es.wikipedia.org/wiki/Semantic_Scholar, outgoing_links: 32
# Tiempo para la página : 1.48 segundos
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/Stephen_Kleene
# URL repetida: https://es.wikipedia.org/wiki/JSTOR
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/Donald_Knuth, outgoing_links: 155
# Tiempo para la página : 1.56 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/Donald_Knuth
# URL repetida: https://es.wikipedia.org/wiki/Semantic_Scholar
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# Página: https://es.wikipedia.org/wiki/A.A._Markov, outgoing_links: 72
# Tiempo para la página : 1.56 segundos
# Página: https://es.wikipedia.org/wiki/Marvin_Minsky, outgoing_links: 93
# Tiempo para la página : 1.67 segundos
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/Emil_Post
# URL repetida: https://es.wikipedia.org/wiki/JSTOR
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/JSTOR
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# URL repetida: https://es.wikipedia.org/wiki/ISBN
# Página: https://es.wikipedia.org/wiki/Proceedings_of_the_London_Mathematical_Society, outgoing_links: 19
# Tiempo para la página : 1.39 segundos
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# URL repetida: https://es.wikipedia.org/wiki/Digital_object_identifier
# Página: https://es.wikipedia.org/wiki/United_States_Patent_and_Trademark_Office, outgoing_links: 77
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/Wikcionario, outgoing_links: 55
# Tiempo para la página : 1.72 segundos
# Página: https://es.wikipedia.org/wiki/Control_de_autoridades, outgoing_links: 7
# Tiempo para la página : 1.58 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Espa%C3%B1a, outgoing_links: 213
# Tiempo para la página : 2.06 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Francia, outgoing_links: 65
# Tiempo para la página : 1.58 segundos
# Página: https://es.wikipedia.org/wiki/Gemeinsame_Normdatei, outgoing_links: 23
# Tiempo para la página : 1.51 segundos
# Página: https://es.wikipedia.org/wiki/Library_of_Congress_Control_Number, outgoing_links: 16
# Tiempo para la página : 1.64 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_la_Dieta, outgoing_links: 43
# Tiempo para la página : 1.58 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_la_Rep%C3%BAblica_Checa, outgoing_links: 28
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/Biblioteca_Nacional_de_Israel, outgoing_links: 40
# Tiempo para la página : 1.53 segundos
# Página: https://es.wikipedia.org/wiki/Art_%26_Architecture_Thesaurus, outgoing_links: 7
# Tiempo para la página : 1.50 segundos
# Página: https://es.wikipedia.org/wiki/Enciclopedia_Brit%C3%A1nica, outgoing_links: 381
# Tiempo para la página : 2.32 segundos
# Página: https://es.wikipedia.org/wiki/Enciclopedia_Treccani, outgoing_links: 90
# Tiempo para la página : 1.62 segundos
# Página: https://es.wikipedia.org/wiki/Medical_Subject_Headings, outgoing_links: 29
# Tiempo para la página : 1.58 segundos
# Página: https://es.wikipedia.org/wiki/Descriptores_en_Ciencias_de_la_Salud, outgoing_links: 37
# Tiempo para la página : 1.32 segundos
# Tiempo para la página : 224.70 segundos
